# %%
x = []

# %%
type(x)
# Out:
# list

# %%
y = [1,2,3,4,5]

# %%
y[1]
# Out:
# 2

# %%
len(y)
# Out:
# 5

# %%
len(x)
# Out:
# 0

# %%
z = [9,10,11,12,13]

# %%
z
# Out:
# [9, 10, 11, 12, 13]

# %%
x = y + z

# %%
x = [0,0,0,0,0]

# %%
x = z + y

# %%
x
# Out:
# [9, 10, 11, 12, 13, 1, 2, 3, 4, 5]

# %%
x[0] = y[0] + z[0]

# %%
x
# Out:
# [10, 10, 11, 12, 13, 1, 2, 3, 4, 5]

# %%
for i in range(5):
    x[i] = y[i] + z[i]

# %%
x
# Out:
# [10, 12, 14, 16, 18, 1, 2, 3, 4, 5]

# %%
s = [0]*5

# %%
s
# Out:
# [0, 0, 0, 0, 0]

# %%
x
# Out:
# [10, 12, 14, 16, 18, 1, 2, 3, 4, 5]

# %%
10 in x
# Out:
# True

# %%
9 in x
# Out:
# False

# %%
letra = 'b'
vogais = ['A','a','E','e','I','i','O','o','U','u']
if letra in vogais:
    print("É uma vogal!")
else:
    print("É uma consoante!")
# Out:
# É uma consoante!

# %%
lista = []

# %%
type(lista)
# Out:
# list

# %%
lista.append(3)

# %%
lista
# Out:
# [3]

# %%
lista.append('Oi')

# %%
lista
# Out:
# [3, 'Oi']

# %%
x = []

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
z
# Out:
# [9, 10, 11, 12, 13]

# %%
for i in range(5):
    x.append(y[i]+z[i])

# %%
x
# Out:
# [10, 12, 14, 16, 18]

# %%
len(x)
# Out:
# 5

# %%
min(x)
# Out:
# 10

# %%
max(x)
# Out:
# 18

# %%
sum(x)
# Out:
# 70

# %%
media = sum(x) / len(x)
print(media)
# Out:
# 14.0

# %%
lista = [3,7,8,9,1,12,4]

# %%
lista
# Out:
# [3, 7, 8, 9, 1, 12, 4]

# %%
sorted(lista)
# Out:
# [1, 3, 4, 7, 8, 9, 12]

# %%
lista.sort()

# %%
lista
# Out:
# [1, 3, 4, 7, 8, 9, 12]

# %%
lista.sort

# %%
palavra = "Abóbora"

# %%
l = list(palavra)

# %%
l
# Out:
# ['A', 'b', 'ó', 'b', 'o', 'r', 'a']

# %%
seq = "123456789"
num = list(seq)

# %%
num
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %%
nomes = ['Ana','Pedro','Bruno','Maria']
for nome in nomes:
    print(nome)
# Out:
# Ana
# Pedro
# Bruno
# Maria

# %%
cidades = []
while True:
    cidade = input("Digite o nome de uma cidade, se quiser sair digite SAIR")
    if cidade.lower() == "sair":
        break
    cidades.append(cidade)
cidades.sort()
for cidade in cidades:
    print(cidade)

# %%
randinnt = (1, 6001)
